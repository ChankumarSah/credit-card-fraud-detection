# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\Hp\\OneDrive\\Desktop\\Machine learning\\creditcard.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [5 rows x 31 columns]

# %%
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 58137    48249.0 -1.069653  0.178872  0.723202 -1.176935 -0.382423 -0.324953
# 104447   69068.0  0.869088 -0.152382  0.043588  1.308112 -0.344703 -0.777964
# 146846   87918.0  2.108361 -0.070936 -2.513788 -0.284893  0.941239 -0.744758
# 139639   83264.0  0.566236 -1.810205 -0.400353 -0.837954 -0.416686  1.346013
# 154190  100909.0  1.945416 -0.514659  0.119076  0.361877 -0.785399  0.159434
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 58137   0.553149  0.170414 -1.929218  ... -0.303471 -0.665904 -0.090771
# 104447  0.489397 -0.174610 -0.449273  ...  0.133463 -0.010402 -0.223548
# 146846  0.598231 -0.285539  0.130709  ...  0.151271  0.421747 -0.100901
# 139639 -0.263620  0.350616 -1.067496  ... -0.095912 -0.293136 -0.159182
# 154190 -1.122656  0.159712  2.490559  ... -0.087276  0.101437  0.277979
#
#              V24       V25       V26       V27       V28  Amount  Class
# 58137  -0.383662  0.575691  1.168527 -0.183873 -0.046377  125.18      0
# 104447  0.544080  0.593343 -0.389620 -0.035258  0.037581  172.72      0
# 146846  0.121490  0.470403  0.227739 -0.105908 -0.087414   22.07      0
# 139639 -0.919518 -0.110608  1.548653 -0.091242  0.023823  331.50      0
# 154190 -0.509569 -0.627291  0.454035 -0.043054 -0.059049   12.95      0
#
# [5 rows x 31 columns]

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 284807
# Columns : 31

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  1.168375e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  3.416908e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -1.379537e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.074095e-15      1.415869   -5.683171     -0.848640
# V5      284807.0  9.604066e-16      1.380247 -113.743307     -0.691597
# V6      284807.0  1.487313e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -5.556467e-16      1.237094  -43.557242     -0.554076
# V8      284807.0  1.213481e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -2.406331e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  2.239053e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  1.673327e-15      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.247012e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  8.190001e-16      0.995274   -5.791881     -0.648539
# V14     284807.0  1.207294e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  4.887456e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.437716e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -3.772171e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  9.564149e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  1.039917e-15      0.814041   -7.213527     -0.456299
# V20     284807.0  6.406204e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.654067e-16      0.734524  -34.830382     -0.228395
# V22     284807.0 -3.568593e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  2.578648e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.473266e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  5.340915e-16      0.521278  -10.295397     -0.317145
# V26     284807.0  1.683437e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660091e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.227390e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
df["Class"].value_counts(normalize=True)*100
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.countplot(x="Class",data=df)

plt.title("Fraud vs Non Fraud")

plt.show()

# %%
plt.figure(figsize=(6,6))

df["Class"].value_counts().plot(
    kind="pie",
    autopct="%1.2f%%",colors=['lightgreen', 'red']
)

plt.ylabel("")

plt.show()

# %%
df.dtypes.value_counts()
# Out:
# float64    30
# int64       1
# Name: count, dtype: int64

# %%
corr=df.corr()

plt.figure(figsize=(18,15))

sns.heatmap(
    corr,
    cmap="coolwarm"
)

plt.show()

# %%
fraud=df[df["Class"]==1]

normal=df[df["Class"]==0]

# %%
print("Fraud :",fraud.shape)

print("Normal :",normal.shape)
# Out:
# Fraud : (473, 31)
# Normal : (283253, 31)

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["Amount"],
    bins=50,
    kde=True
)

plt.title("Transaction Amount")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["Time"],
    bins=50
)

plt.show()

# %%
plt.figure(figsize=(10,3))

sns.boxplot(
    x=df["Amount"]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Class",
    y="Amount",
    data=df
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x="Class",
    y="Time",
    data=df
)

plt.show()

# %%
df.hist(
    figsize=(20,20),
    bins=30
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(
    df["Amount"],
    fill=True
)

plt.show()

# %%
sample=df.sample(1000,random_state=42)

sns.pairplot(
    sample[
        ["Amount","Time","V1","V2","Class"]
    ],
    hue="Class"
)

plt.show()

# %%
Q1=df["Amount"].quantile(0.25)

Q3=df["Amount"].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR

upper=Q3+1.5*IQR

print(lower)

print(upper)
# Out:
# -102.26500000000001
# 185.375

# %%
outliers=df[
    (df["Amount"]<lower)
    |
    (df["Amount"]>upper)
]

outliers.shape
# Out:
# (31685, 31)

# %%
df.skew()
# Out:
# Time      -0.035581
# V1        -3.273271
# V2        -4.695162
# V3        -2.151984
# V4         0.671504
# V5        -2.414079
# V6         1.829880
# V7         2.890271
# V8        -8.310970
# V9         0.537663
# V10        1.252967
# V11        0.344074
# V12       -2.199008
# V13        0.064293
# V14       -1.918804
# V15       -0.309659
# V16       -1.051161
# V17       -3.690497
# V18       -0.248661
# V19        0.108312
# V20       -2.043121
# V21        2.820033
# V22       -0.182330
# V23       -5.867221
# V24       -0.552129
# V25       -0.415744
# V26        0.580292
# V27       -0.753804
# V28       11.555115
# Amount    16.978803
# Class     24.430545
# dtype: float64

# %%
df.groupby("Class")["Amount"].describe()
# Out:
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      283253.0   88.413575  250.379023  0.0  5.67  22.00   77.46  25691.16
# 1         473.0  123.871860  260.211041  0.0  1.00   9.82  105.89   2125.87

# %%
corr=df.corr()["Class"].sort_values()

corr
# Out:
# V17      -0.313498
# V14      -0.293375
# V12      -0.250711
# V10      -0.206971
# V16      -0.187186
# V3       -0.182322
# V7       -0.172347
# V18      -0.105340
# V1       -0.094486
# V9       -0.094021
# V5       -0.087812
# V6       -0.043915
# Time     -0.012359
# V24      -0.007210
# V23      -0.006333
# V13      -0.003897
# V15      -0.003300
# V25       0.003202
# V26       0.004265
# V22       0.004887
# Amount    0.005777
# V28       0.009682
# V20       0.021486
# V27       0.021892
# V21       0.026357
# V8        0.033068
# V19       0.033631
# V2        0.084624
# V4        0.129326
# V11       0.149067
# Class     1.000000
# Name: Class, dtype: float64

# %%
plt.figure(figsize=(8,10))

corr.plot(kind="barh")

plt.show()

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

print("Feature Shape :", X.shape)
print("Target Shape :", y.shape)
# Out:
# Feature Shape : (283726, 30)
# Target Shape : (283726,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Shape :", X_train.shape)
print("Testing Shape :", X_test.shape)
# Out:
# Training Shape : (226980, 30)
# Testing Shape : (56746, 30)

# %%
print(y_train.value_counts())

print("\nPercentage")

print(y_train.value_counts(normalize=True)*100)
# Out:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64
#
# Percentage
# Class
# 0    99.833466
# 1     0.166534
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x=y_train)
plt.title("Class Distribution Before SMOTE")
plt.show()

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_smote, y_train_smote = smote.fit_resample(
    X_train,
    y_train
)

# %%
print(y_train_smote.value_counts())
# Out:
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=y_train_smote)
plt.title("Class Distribution After SMOTE")
plt.show()

# %%
# ============================================================
# Final Model Training using Pipeline
# ============================================================

from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# Pipeline (Scaler already applied manually)
logistic_pipeline = Pipeline([
    ("classifier", LogisticRegression(
        class_weight="balanced",
        random_state=42,
        max_iter=1000
    ))
])

# Train Pipeline
logistic_pipeline.fit(X_train_scaled, y_train_smote)

print("✅ Logistic Regression Pipeline Trained Successfully")
# Out:
# ✅ Logistic Regression Pipeline Trained Successfully

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

# Prediction
y_pred = logistic_pipeline.predict(X_test_scaled)
y_prob = logistic_pipeline.predict_proba(X_test_scaled)[:, 1]

print("="*50)
print("Model Performance")
print("="*50)

print(f"Accuracy : {accuracy_score(y_test, y_pred):.4f}")
print(f"Precision: {precision_score(y_test, y_pred):.4f}")
print(f"Recall   : {recall_score(y_test, y_pred):.4f}")
print(f"F1 Score : {f1_score(y_test, y_pred):.4f}")
print(f"ROC AUC  : {roc_auc_score(y_test, y_prob):.4f}")

print("\nClassification Report")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred))
# Out:
# ==================================================
# Model Performance
# ==================================================
# Accuracy : 0.9911
# Precision: 0.1411
# Recall   : 0.8526
# F1 Score : 0.2422
# ROC AUC  : 0.9607
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56651
#            1       0.14      0.85      0.24        95
#
#     accuracy                           0.99     56746
#    macro avg       0.57      0.92      0.62     56746
# weighted avg       1.00      0.99      0.99     56746
#
#
# Confusion Matrix
# [[56158   493]
#  [   14    81]]

# %%
import joblib

joblib.dump(logistic_pipeline, "logistic_regression_pipeline.pkl")

print("✅ Model saved successfully in the current directory!")
# Out:
# ✅ Model saved successfully in the current directory!

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42)}

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),

    "Decision Tree": DecisionTreeClassifier(random_state=42),

    "Random Forest": RandomForestClassifier(random_state=42),

    "XGBoost": XGBClassifier(
        random_state=42,
        eval_metric="logloss"
    ),

    "LightGBM": LGBMClassifier(random_state=42)
}

# %%
results = []

for name, model in models.items():

    model.fit(X_train_scaled, y_train_smote)

    y_pred = model.predict(X_test_scaled)

    y_prob = model.predict_proba(X_test_scaled)[:,1]

    results.append({

        "Model":name,

        "Accuracy":accuracy_score(y_test,y_pred),

        "Precision":precision_score(y_test,y_pred),

        "Recall":recall_score(y_test,y_pred),

        "F1 Score":f1_score(y_test,y_pred),

        "ROC AUC":roc_auc_score(y_test,y_prob)

    })

# %%
results_df = pd.DataFrame(results)

results_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0  Logistic Regression  0.991065   0.141115  0.852632  0.242152  0.960748

# %%
results_df.sort_values(
    by="ROC AUC",
    ascending=False
)
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0  Logistic Regression  0.991065   0.141115  0.852632  0.242152  0.960748

# %%
results_df.style.highlight_max(
    color="lightgreen"
)

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="Model",
    y="ROC AUC"
)

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="Model",
    y="F1 Score"
)

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="Model",
    y="Accuracy"
)

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="Model",
    y="Precision"
)

plt.xticks(rotation=20)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=results_df,
    x="Model",
    y="Recall"
)

plt.xticks(rotation=20)

plt.show()

# %%
best_model_name = results_df.sort_values(
    by="ROC AUC",
    ascending=False
).iloc[0]["Model"]

print(best_model_name)
# Out:
# Logistic Regression

# %%
best_model = models[best_model_name]
